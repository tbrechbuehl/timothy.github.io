# %% [markdown]
# <a href="https://colab.research.google.com/github/tbrechbuehl/timothy.github.io/blob/main/notebooks/Regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os

# Execute this code only if in colab
if 'COLAB_GPU' in os.environ:
  print("Executing in Colab!")
  # Cloning GitHub repository
  # !git clone https://github.com/fwitschel/ML.git
  # %cd ML
# Out:
# Executing in Colab!
# Cloning into 'ML'...
# remote: Enumerating objects: 86, done.
# remote: Counting objects: 100% (86/86), done.
# remote: Compressing objects: 100% (83/83), done.
# remote: Total 86 (delta 31), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (86/86), 1.55 MiB | 4.82 MiB/s, done.
# Resolving deltas: 100% (31/31), done.
# /content/ML

# %%
import pandas as pd
import numpy as np
from sklearn import metrics
from sklearn import tree
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import accuracy_score
import xgboost as xg
from sklearn.tree import DecisionTreeClassifier
from matplotlib import pyplot as plt

# %%
days = pd.read_csv("/content/ML/data/02 SkierDays-regression-final.csv")
days.head()
# Out:
#          DATE  DAY  MONTH  IS_WEEKEND  WIND_DIRECTION  WIND_SPEED  \
# 0  01.01.2013    1      1       False      265.833333   20.829167
# 1  02.01.2013    2      1       False      257.083333   13.283333
# 2  03.01.2013    3      1       False      261.666667   13.125000
# 3  04.01.2013    4      1       False      148.333333   24.620833
# 4  05.01.2013    5      1        True      105.000000   31.862500
#
#    PEAK_WIND_SPEED  TEMPERATURE  DEW_POINT  MAX_TEMPERATURE_DAY  ...  \
# 0        39.137500    -4.495833 -11.279167                  0.0  ...
# 1        29.000000    -7.883333  -9.766667                  0.0  ...
# 2        31.687500    -2.141667 -12.958333                  0.7  ...
# 3        64.129167    -0.858333  -1.479167                  0.0  ...
# 4        68.454167    -1.533333  -2.762500                  0.0  ...
#
#    IS_HOLIDAY  ARRIVALS_DOMESTIC  ARRIVALS_FOREIGN  DURATION_DOMESTIC  \
# 0        True                NaN               NaN                NaN
# 1        True                NaN               NaN                NaN
# 2        True                NaN               NaN                NaN
# 3        True                NaN               NaN                NaN
# 4        True                NaN               NaN                NaN
#
#    DURATION_FOREIGN  OVERNIGHTS_DOMESTIC  OVERNIGHTS_FOREIGN  TOTAL_ARRIVALS  \
# 0               NaN                  NaN                 NaN             NaN
# 1               NaN                  NaN                 NaN             NaN
# 2               NaN                  NaN                 NaN             NaN
# 3               NaN                  NaN                 NaN             NaN
# 4               NaN                  NaN                 NaN             NaN
#
#    TOTAL_DURATION  TOTAL_OVERNIGHTS
# 0             NaN               NaN
# 1             NaN               NaN
# 2             NaN               NaN
# 3             NaN               NaN
# 4             NaN               NaN
#
# [5 rows x 29 columns]
# Warning: Total number of columns (29) exceeds max_columns (20) limiting to first (20) columns.

# %%
feature_cols = ['Agent Experience','Agent Name','Customer Type','Priority','Problem Category','Ticket Type','Severity']

# Die Tabelle mit den Features heisst in Python oft "X"
X = days[feature_cols]

# Das Klassenattribut / die Zielvariable wird in Python gern "y" genannt
y = fixit.SLAFullfillment
